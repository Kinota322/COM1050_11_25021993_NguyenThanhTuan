# %%
#1
n = int(input())
print(n * 2)
# Out:
# 6

# %%
#2
a, b = map(int, input().split())
pi = 3.14
r = min(a, b)
print(f'{(a * b - pi * r):.2f}')
# Out:
# 5.58

# %%
#3
a = input()
if ord('A') <= ord(a) <= ord('Z'):
    print(chr(ord(a) - (ord('A') - ord('a'))))
else:
    print(chr(ord(a) + (ord('A') - ord('a'))))
# Out:
# G

# %%
#4
a = input()
if ord('A') <= ord(a) <= ord('Z') or ord('a') <= ord(a) <= ord('z'):
    print(a, 'la ki tu alphabet')
else:
    print(a, 'khong phai la ki tu alphabet')
# Out:
# t la ki tu alphabet

# %%
#5
a = input()
print(chr(ord(a) - (ord('A') - ord('a') + 1)))
# Out:
# a

# %%
#6
import math
a, b, c = map(int, input().split())

if a + b > c or a + c > b or b + c > a:
    p = (a + b + c) / 2
    print(f'{((p * (p - a) * (p - b) * (p - c))**(1/2)):.1f}')
else:
    print('Khong phai 3 canh cua tam giac')
# Out:
# 6.0

# %%
#7
string = input()
print(string[4], string[8])
# Out:
# 5 9

# %%
#8
ho_va_ten = input('Ten chu ho: ')
chi_so_thang_truoc = int(input('Chi so thang truoc: '))
chi_so_thang_nay = int(input('Chi so thang nay: '))

so_dien = chi_so_thang_nay - chi_so_thang_truoc

tong_tien = 0

if so_dien <= 50:
    tong_tien = so_dien * 1984
elif so_dien <= 100:
    tong_tien = 50 * 1984 + (so_dien - 50) * 2050
elif so_dien <= 200:
    tong_tien = 50 * 1984 + 50 * 2050 + (so_dien - 100) * 2380
elif so_dien <= 300:
    tong_tien = 50 * 1984 + 50 * 2050 + 100 * 2380 + (so_dien - 200) * 2998
elif so_dien <= 400:
    tong_tien = 50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + (so_dien - 300) * 3350
else:
    tong_tien = 50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + 100 * 3350 + (so_dien - 400) * 3460

print(f'{(tong_tien * (108/100)):.0f}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 6
#       3 chi_so_thang_truoc = input('Chi so thang truoc: ')
#       4 chi_so_thang_nay = input('Chi so thang nay: ')
# ----> 6 so_dien = chi_so_thang_nay - chi_so_thang_truoc
#       8 tong_tien = 0
#      10 if so_dien <= 50:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
