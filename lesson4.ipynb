# %%
#1
n = int(input())

sum = 0

for i in range(1, n + 1):
    sum += i
print(sum)

# %%
#2
def check(num):
    if num <= 1:
        return False
    for i in range(2, int((num ** (1/ 2)) + 1)):
        if num % i == 0:
            return False
    return True

while(True):
    n = int(input())
    if n <= 0:
        continue
    print(check(n))
    break

# %%
#3
n = int(input())

res = 1

for i in range(1, n + 1):
    res *= i
print(res)

# %%
#4
n = int(input())
n = abs(n)
res = 0
while n:
    res += 1
    n //= 10
print(res)

# %%
#5
n = int(input())
a = list(map(int, input().split()))

if 42 in a:
    print("I've found the meaning of life!")
else:
    print("It's a joke!")

# %%
#6

def prime_num(num):
    if num <= 1:
        return False
    for i in range(2, int((num ** (1/ 2)) + 1)):
        if num % i == 0:
            return False
    return True

def solve(s1, s2):
    res = 0
    for i in range(s1, s2 + 1):
        if prime_num(i):
            res += i
    return res

while(True):
    a, b = map(int, input().split())
    print(solve(a, b))

# %%
#7
def prime_num(num):
    if num <= 1:
        return False
    for i in range(2, int((num ** (1/ 2)) + 1)):
        if num % i == 0:
            return False
    return True

n = int(input())
res = (prime_num(n) == True) * n
for i in range(1, int((n ** (1/2)) + 1)):
    if n % i == 0:
        res = max(res, (n / i) * prime_num(int(n / i)))
        res = max(res, i * prime_num(i))
print(res)

# %%
#8
def rev(num):
    res = 0
    while num:
        res *= 10
        res += num % 10
        num //= 10
    return res

n = int(input())
cnt = 0
while n != rev(n):
    cnt += 1
    n = n + rev(n)
print(cnt, n)

# %%
#9
n = int(input())
i = 1
while i * i <= n:
    print(i * i, end = ' ')
    i += 1

# %%
#10
n = int(input())
def len_collatz(num):
    cnt = 1
    while num != 1:
        cnt += 1
        if num & 1:
            num = (3 * num) + 1
        else:
            num = num // 2
    return cnt

num_res = 1
res = 1
for i in range(1, n + 1):
    temp = len_collatz(i)
    if temp > res:
        num_res = i
        res = len_collatz(i)

print(num_res, res)

# %%
#11
n = int(input())

res = 0

for i in range(1, n + 1):
    if n % i == 0:
        res += 1 * ((n // i) & 1 == 0)
    
print(res)

# %%
#12
a, b = map(int, input().split())

print((a * ((1.007) ** b)) // 1)

# %%
#13
def tong_uoc(num):
    res = 1
    for i in range(2, int((num ** (1/ 2)) + 1)):
        if num % i == 0:
            res += i
            if (num // i) != i:
                res += num // i
    return res
a, b = map(int, input().split())

if tong_uoc(a) == b and a == tong_uoc(b):
    print('true')
else:
    print('false')

# %%
#14
import math

a, b = map(int, input().split())

print(math.gcd(a, b))

# %%
#15
so_con, so_chan = map(int, input().split())

if so_chan % 2 != 0 or (so_chan // 2 - so_con < 0):
    print('invalid')
else:
    cho = so_chan // 2 - so_con
    ga = so_con - cho
    print(ga, cho)

# %%
#16
for i in range(6, 100, 6):
    print(i)

# %%
#17
a = int(input())
for i in range(1, 11):
    print(f'{i} * {a} = {i * a}')

# %%
#18
a, b = map(int, input().split())
for i in range(1, max(a, b) + 1):
    if a % i == 0 and b % i == 0:
        print(i, end = ' ')

# %%
#19
n = int(input())
for i in range(2, n + 1, 2):
    print(i)

# %%
#20
n = int(input())
temp = 1
while temp < n:
    temp = temp << 1
if temp == n:
    print('Yes')
else:
    print('No')

# %%
#21
n = input()
res = 0
for i in n:
    res += int(i)
print(res)

# %%
#22
n = input()
odd_n = 0
even_n = 0
for i in n:
    if int(i) & 1:
        even_n += 1
    else:
        odd_n += 1

print(f'So luong chu so chan: {even_n} va so luong chu so le: {odd_n}')

# %%
#23
n = int(input())

res = 0
cnt = 1

while res + cnt <= n:
    res += cnt
    cnt += 1

print(res)

# %%
#24
n = float(input())

res = 0
cnt = 1

while res <= n:
    res += 1/cnt
    cnt += 1
print(cnt - 1)

# %%
#25
import math
inp = 0
mx = 0
mn = 0
cnt = 0
while inp != -1:
    inp = int(input())
    if cnt == 0:
        mx = inp
        mn = inp
        cnt += 1
    mx = int(max(inp, int(mx)))
    mn = int(min(inp, int(mn)))
print(f'max: {mx}, min: {mn}')

# %%
#26
a = int(input())
f1 = 0
f2 = 1
while f1 + f2 <= a:
    f1, f2 = f2, f1 + f2
print(f2)
#1 1 2 3 5 8 13

# %%
#27
string = input()
cnt = 0
for i in string:
    if ord('a') <= ord(i) <= ord('z') or ord('A') <= ord(i) <= ord('Z'):
        cnt += 1
print(cnt)

# %%
#28
string = input()
for i in string:
    if ord('a') <= ord(i) <= ord('z') or ord('A') <= ord(i) <= ord('Z'):
        print(i) 
        break

# %%
#29
a, b, c = input().split(', ')
print(a + b + c)

# %%
#30
string = input()
in_hoa = 0
in_thuong = 0
so = 0
for i in string:
    if ord('a') <= ord(i) <= ord('z'):
        in_thuong += 1
    elif ord('A') <= ord(i) <= ord('Z'):
        in_hoa += 1
    elif ord('0') <= ord(i) <= ord('9'):
        so += 1
print(f'In hoa: {in_hoa}, in thuong: {in_thuong}, so: {so}')

# %%
#31
string = input()
res = 0
for i in string:
    if ord('0') <= ord(i) <= ord('9'):
        res += ord(i) - ord('0')
print(res)

# %%
#32
password = input()

in_hoa = in_thuong = so = ktdb = False

for i in password:
    if ord('a') <= ord(i) <= ord('z'):
        in_thuong = True
    elif ord('A') <= ord(i) <= ord('Z'):
        in_hoa = True
    elif ord('0') <= ord(i) <= ord('9'):
        so = True
    else:
        ktdb = True
if in_thuong and in_hoa and so and ktdb:
    print(f'{password} la mat khau manh')
else:
    print(f'{password} khong phai la mat khau manh')

# %%
#33
n = int(input())
n = str(n)
n = n[::-1]
cnt = 0
res = ''
for i in n:
    cnt += 1
    res += i
    if (cnt % 3 == 0) and (cnt != len(n)):
        res += '.'
print(res[::-1])

# %%
#34
a = input()
b = input()

for i in range(0, len(a) - len(b) + 1):
    if a[i:(i + len(b)):1] == b:
        a = a[0:i:1] + a[(i + len(b)):len(a):1]
        break
print(a)
